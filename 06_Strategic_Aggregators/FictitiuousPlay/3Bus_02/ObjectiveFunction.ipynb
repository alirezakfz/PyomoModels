# %%
# Import packages
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

# %%
df =pd.read_csv('objective_20210827-064637.csv')

# %%
df
# Out:
#                 1                   2                   3
# 0     6449.454971   4923.831077386198   6420.731159589064
# 1    10226.423605   9599.272222718946  11063.664938808228
# 2     8037.895246   8881.513378565169  10331.769804299161
# 3     8761.171242  11014.425059378205   11775.17625692009
# 4     8062.598113  11013.371941326246   11788.48281057449
# ..            ...                 ...                 ...
# 496   8802.386534                 NAN   7419.691978061157
# 497   8802.386534                 NAN                 NAN
# 498   8802.386534   9616.695215946154   9607.450165730765
# 499   8101.620164   9631.412568702935   9609.152418463014
# 500   8101.620164                 NAN   9609.152418463014
#
# [501 rows x 3 columns]

# %%
#df['3'][df['3']==max(df['3'])]=max(df['2'])

# %%
counter=0
for col in df.columns:
    #df[col][df[col]=='NAN']=np.nan
    #print(df[col].isna().sum())
#     print(df[col][df[col]=='NAN'].index)
    index=df[col][df[col]=='NAN'].index
    if(len(index) > 0):
        df.loc[index,col]=np.nan

for col in df.columns:
    df[col]=pd.to_numeric(df[col])

# %%
for col in df.columns:
    #df[col].fillna(value=df[col].mean(), inplace=True)
    print(col)
    print(df[col].isna().sum())
    print(df[col].mean())
# Out:
# 1
# 0
# 8399.197358588926
# 2
# 82
# 8910.537618780676
# 3
# 67
# 9264.054748927483

# %%
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
is_numeric_dtype(df['3'])
# Out:
# True

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
x=np.arange(501)
y=df['1']
ax.plot(x,y)
y=df['2']
ax.plot(x,y)
y=df['3']
ax.plot(x,y)
ax.legend(['DA1','DA2','DA3'],loc='upper right')
plt.xlabel("Iterations")
plt.ylabel("Objective Function")
plt.title("Diagonalization Method")
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('Objective_Function.png', dpi=100)

# %%
for col in df.columns:
    df[col].fillna(value=df[col].mean(), inplace=True)

# %%
# after filling NAN with mean
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
x=np.arange(501)
y=df['1']
ax.plot(x,y)
y=df['2']
ax.plot(x,y)
y=df['3']
ax.plot(x,y)
ax.legend(['DA1','DA2','DA3'],loc='upper right')
plt.xlabel("Iterations")
plt.ylabel("Objective Function")
plt.title("Diagonalization Method")
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('Objective_Function.png', dpi=100)

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
x=np.arange(501)
y=df['3']
ax.plot(x,y)
plt.show()

# %%
np.argmax(df.sum(axis=1))
# Out:
# 173

# %%
df.loc[173,'1'], df.loc[173,'2'], df.loc[173,'3']
# Out:
# (9530.246652983427, 11081.103199338966, 12541.324542081173)

# %%
import seaborn as sns
# sns.set()

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
# Histogram
fig = plt.figure(figsize=(15,5))
# ax = fig.add_subplot(111)
for col in df.columns:
    ax = sns.kdeplot(df[col], shade=True, legend=True)
ax.set(xlabel='Objective Function value of MPEC', title='Kernel Density plot')
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
plt.legend(loc='upper right', labels=['DA1', 'DA2', 'DA3'])
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('Objective_Function_Density.png', dpi=100)

# %%
max(df['3'])
# Out:
# 1088.8818372784822

# %% [markdown]
# ### 3d Plot function values

# %%
# https://www.python-graph-gallery.com/371-surface-plot

data = pd.read_csv('objective_20210827-064637.csv')
data.columns=["DA1","DA2","DA3"]

for col in data.columns:
    index=data[col][data[col]=='NAN'].index
    if(len(index) > 0):
        data.loc[index,col]=np.nan

            
for col in data.columns:
    data[col]=pd.to_numeric(data[col])
    
for col in data.columns:
    data[col].fillna(value=data[col].mean(), inplace=True)
  
# Transform it to a long format
df=data.unstack().reset_index()
df.columns=["X","Y","Z"]

# And transform the old column name in something numeric
df['X']=pd.Categorical(df['X'])
df['X']=df['X'].cat.codes

# %%
data
# Out:
#               DA1           DA2           DA3
# 0     6449.454971   4923.831077   6420.731160
# 1    10226.423605   9599.272223  11063.664939
# 2     8037.895246   8881.513379  10331.769804
# 3     8761.171242  11014.425059  11775.176257
# 4     8062.598113  11013.371941  11788.482811
# ..            ...           ...           ...
# 496   8802.386534   8910.537619   7419.691978
# 497   8802.386534   8910.537619   9264.054749
# 498   8802.386534   9616.695216   9607.450166
# 499   8101.620164   9631.412569   9609.152418
# 500   8101.620164   8910.537619   9609.152418
#
# [501 rows x 3 columns]

# %%
df
# Out:
#       X    Y             Z
# 0     0    0   6449.454971
# 1     0    1  10226.423605
# 2     0    2   8037.895246
# 3     0    3   8761.171242
# 4     0    4   8062.598113
# ...  ..  ...           ...
# 1498  2  496   7419.691978
# 1499  2  497   9264.054749
# 1500  2  498   9607.450166
# 1501  2  499   9609.152418
# 1502  2  500   9609.152418
#
# [1503 rows x 3 columns]

# %%
# Make the plot
fig = plt.figure(figsize=(8,8))
# ax = fig.gca(projection='3d')
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf( df['Y'], df['X'] , df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
plt.show()

# %%
df['X'].max()
# Out:
# 2

# %%
# Get the data (csv file is hosted on the web)
url = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/volcano.csv'
data = pd.read_csv(url)

# %%
data
# Out:
#      V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  ...  V52  V53  V54  V55  \
# 0   100  100  101  101  101  101  101  100  100  100  ...  107  107  107  106
# 1   101  101  102  102  102  102  102  101  101  101  ...  108  108  107  107
# 2   102  102  103  103  103  103  103  102  102  102  ...  109  108  108  107
# 3   103  103  104  104  104  104  104  103  103  103  ...  109  109  108  108
# 4   104  104  105  105  105  105  105  104  104  103  ...  110  109  109  108
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 82   99   99   99   99  100  100  101  101  102  102  ...   95   95   95   95
# 83   98   99   99   99   99  100  100  101  101  102  ...   95   95   94   94
# 84   98   98   98   99   99   99  100  100  101  101  ...   94   94   94   94
# 85   97   98   98   98   99   99   99  100  100  100  ...   94   94   94   94
# 86   97   97   97   98   98   99   99   99  100  100  ...   94   94   94   94
#
#     V56  V57  V58  V59  V60  V61
# 0   106  105  105  104  104  103
# 1   106  106  105  105  104  104
# 2   107  106  106  105  105  104
# 3   107  107  106  106  105  105
# 4   107  107  107  106  106  105
# ..  ...  ...  ...  ...  ...  ...
# 82   94   94   94   94   94   94
# 83   94   94   94   94   94   94
# 84   94   94   94   94   94   94
# 85   94   94   94   94   94   94
# 86   94   94   94   94   94   94
#
# [87 rows x 61 columns]

# %%
df=data.unstack().reset_index()
df.columns=["X","Y","Z"]

# %%
df
# Out:
#         X   Y    Z
# 0      V1   0  100
# 1      V1   1  101
# 2      V1   2  102
# 3      V1   3  103
# 4      V1   4  104
# ...   ...  ..  ...
# 5302  V61  82   94
# 5303  V61  83   94
# 5304  V61  84   94
# 5305  V61  85   94
# 5306  V61  86   94
#
# [5307 rows x 3 columns]

# %%
# And transform the old column name in something numeric
df['X']=pd.Categorical(df['X'])
df['X']=df['X'].cat.codes
 
# Make the plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
plt.show()
# Out:
# <ipython-input-32-22098345a761>:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
df
# Out:
#        X   Y    Z
# 0      0   0  100
# 1      0   1  101
# 2      0   2  102
# 3      0   3  103
# 4      0   4  104
# ...   ..  ..  ...
# 5302  57  82   94
# 5303  57  83   94
# 5304  57  84   94
# 5305  57  85   94
# 5306  57  86   94
#
# [5307 rows x 3 columns]

# %% [markdown]
# ## Method 2

# %%
#  https://stackoverflow.com/a/68092340

def plottable_3d_info(df: pd.DataFrame):
    """
    Transform Pandas data into a format that's compatible with
    Matplotlib's surface and wireframe plotting.
    """
    index = df.index
    columns = df.columns

    x, y = np.meshgrid(np.arange(len(columns)), np.arange(len(index)))
    z = np.array([[df[c][i] for c in columns] for i in index])
    
    xticks = dict(ticks=np.arange(len(columns)), labels=columns)
    yticks = dict(ticks=np.arange(len(index)), labels=index)
    
    return x, y, z, xticks, yticks

# %%
data = pd.read_csv('objective_20210817-213751.csv')
data.columns=["DA1","DA2","DA3"]

### Transform to Matplotlib friendly format.
x, y, z, xticks, yticks = plottable_3d_info(data)

# %%
z
# Out:
# array([[373.74553064, 358.48665911, 336.47733708],
#        [386.20032954, 370.00863879, 336.60617899],
#        [386.96856128, 368.70789131, 337.1626508 ],
#        ...,
#        [380.95138959, 347.36318139, 331.5624383 ],
#        [386.8534438 , 368.71383788, 336.47733708],
#        [387.43594984, 368.70789131, 337.9572466 ]])

# %%
### Set up axes and put data on the surface.
axes = plt.figure().gca(projection='3d')
axes.plot_surface(x, y, z)
# Out:
# <ipython-input-47-275c2f71ae20>:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axes = plt.figure().gca(projection='3d')

# %%
fig = plt.figure(figsize=(8,8))
# ax = fig.gca(projection='3d')
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface( x,y,z, cmap=plt.cm.viridis, linewidth=0.2)
plt.show()

# %% [markdown]
# ## Method 3: remove one column

# %%
data = pd.read_csv('objective_20210817-213751.csv')
data.columns=["DA1","DA2","DA3"]

data.drop(columns=['DA1'], inplace=True)

# %%
### Transform to Matplotlib friendly format.
x, y, z, xticks, yticks = plottable_3d_info(data)

# %%
fig = plt.figure(figsize=(8,8))
# ax = fig.gca(projection='3d')
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface( x,y,z, cmap=plt.cm.viridis, linewidth=0.2)
plt.show()

# %%
data = pd.read_csv('objective_20210817-213751.csv')
data.columns=["DA1","DA2","DA3"]
data
# Out:
#             DA1         DA2         DA3
# 0    373.745531  358.486659  336.477337
# 1    386.200330  370.008639  336.606179
# 2    386.968561  368.707891  337.162651
# 3    386.200799  370.488446  339.281505
# 4    379.667978  369.437642  336.994225
# ..          ...         ...         ...
# 495  388.276850  370.736715  341.160014
# 496  385.345152  360.441176  338.582654
# 497  380.951390  347.363181  331.562438
# 498  386.853444  368.713838  336.477337
# 499  387.435950  368.707891  337.957247
#
# [500 rows x 3 columns]
