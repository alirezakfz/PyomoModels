# %%
# %matplotlib inline

import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_diag = pd.read_csv("diagonalizaton_results_diag.csv")
df_ahe = pd.read_csv("diagonalizaton_results_AHE.csv")
df_fp = pd.read_csv("diagonalizaton_results_FP.csv")
# df_sfp = pd.read_csv("diagonalizaton_results_SFP.csv")

# %% [markdown]
# ## DA1 in algorithms

# %%
offer_col = "offer_01"

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    offer_t = df_ahe[df_ahe.Time==t][offer_col]
    plt.plot(range((len(offer_t))), offer_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Offer for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 10 epochs for DA 1 in AH algorithm')
# ax.legend(['prosumer 1', 'prosumer 2'])
# ax.set_xticklabels(range(291,292+len(offer_t)))
plt.savefig("DA1_10_last_epochs_offers_AH.png")

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    offer_t = df_fp[df_fp.Time==t][offer_col][141:]
    plt.plot(range((len(offer_t))), offer_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Offer for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 10 epochs for DA 1 in FP algorithm')
# ax.legend(['prosumer 1', 'prosumer 2'])
ax.set_xticklabels(range(141,142+len(offer_t)))
plt.savefig("DA1_10_last_epochs_offers_FP.png")
# Out:
# C:\Users\Alireza\AppData\Local\Temp/ipykernel_18352/411328193.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(range(141,142+len(offer_t)))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    offer_t = df_sfp[df_sfp.Time==t][offer_col][291:]
    plt.plot(range((len(offer_t))), offer_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Offer for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 10 epochs for DA 1 in SFP algorithm')
# ax.legend(['prosumer 1', 'prosumer 2'])
ax.set_xticklabels(range(291,292+len(offer_t)))
plt.savefig("DA1_10_last_epochs_offers_SFP.png")
# Out:
# C:\Users\Alireza\AppData\Local\Temp/ipykernel_8188/3726757956.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(range(291,292+len(offer_t)))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    bids_t = df_diag[df_diag.Time==t][offer_col]
    plt.plot(range((len(bids_t))), bids_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Bids for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 6 epochs for DA 1 in SFP')
# ax.set_xticklabels(range(145,146+len(bids_t)))
# ax.legend(['prosumer 1', 'prosumer 2'])
# plt.savefig("DA1_10_last_epochs_bids_diag.eps")
# plt.savefig("DA1_10_last_epochs_bids_diag.png")
# Out:
# Text(0.5, 1.0, 'The last 6 epochs for DA 1 in SFP')

# %% [markdown]
# ## DA2 in algorithms

# %%
offer_col = "offer_02"

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    offer_t = df_ahe[df_ahe.Time==t][offer_col][291:]
    plt.plot(range((len(offer_t))), offer_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Offer for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 10 epochs for DA 2 in AH algorithm')
# ax.legend(['prosumer 1', 'prosumer 2'])
ax.set_xticklabels(range(291,292+len(offer_t)))
plt.savefig("DA2_10_last_epochs_offers_AH.png")
# Out:
# C:\Users\Alireza\AppData\Local\Temp/ipykernel_8188/2969101472.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(range(291,292+len(offer_t)))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    offer_t = df_fp[df_fp.Time==t][offer_col][141:]
    plt.plot(range((len(offer_t))), offer_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Offer for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 10 epochs for DA 2 in FP algorithm')
# ax.legend(['prosumer 1', 'prosumer 2'])
ax.set_xticklabels(range(141,142+len(offer_t)))
plt.savefig("DA2_10_last_epochs_offers_FP.png")
# Out:
# C:\Users\Alireza\AppData\Local\Temp/ipykernel_8188/1479168212.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(range(141,142+len(offer_t)))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    offer_t = df_sfp[df_sfp.Time==t][offer_col][291:]
    plt.plot(range((len(offer_t))), offer_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Offer for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 10 epochs for DA 2 in SFP algorithm')
# ax.legend(['prosumer 1', 'prosumer 2'])
ax.set_xticklabels(range(291,292+len(offer_t)))
plt.savefig("DA2_10_last_epochs_offers_SFP.png")
# Out:
# C:\Users\Alireza\AppData\Local\Temp/ipykernel_8188/1314746570.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(range(291,292+len(offer_t)))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in range(16,40):
    bids_t = df_diag[df_diag.Time==t][bid_col]
    plt.plot(range((len(bids_t))), bids_t)
    


# plt.plot(range(len(pros1)), pros1)
# plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("Bids for each 24 of time slots in MWh")
ax.set_xlabel("Epochs number")
ax.set_title('The last 6 epochs for DA 2 in Diag')
# ax.set_xticklabels(range(145,146+len(bids_t)))
# ax.legend(['prosumer 1', 'prosumer 2'])
# plt.savefig("DA2_10_last_epochs_bids_FP.eps")
# plt.savefig("DA2_10_last_epochs_bids_FP.png")
# Out:
# Text(0.5, 1.0, 'The last 6 epochs for DA 2 in Diag')
