# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("simulation_profile0.csv")

# %%
df2=pd.read_csv("simulation_profile1.csv")

# %%
df1.drop(columns=["Unnamed: 0","reference","November","Minute_of_day"], inplace=True)

# %%
df1.sum(axis=1).plot()
# Out:
# <AxesSubplot:>

# %%
df2.drop(columns=["Unnamed: 0","reference","November","Minute_of_day"], inplace=True)

# %%
df2.sum(axis=1).plot()
# Out:
# <AxesSubplot:>

# %%
pros1=df1.sum(axis=1)
pros2=df2.sum(axis=1)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(range(len(pros1)), pros1)
plt.plot(range(len(pros2)), pros2)
ax.set_ylabel("KWh")
ax.set_xlabel("Time in minute")
ax.set_title('Example of syntethic demand for two prosumers')
ax.legend(['prosumer 1', 'prosumer 2'])
plt.savefig("prosumers.eps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-78df44515d94> in <module>
#       7 ax.set_title('Example of syntethic demand for two prosumers')
#       8 ax.legend(['prosumer 1', 'prosumer 2'])
# ----> 9 plt.savefig(prosumers.eps)
#
# NameError: name 'prosumers' is not defined

# %%
# Out:
# 52.0
