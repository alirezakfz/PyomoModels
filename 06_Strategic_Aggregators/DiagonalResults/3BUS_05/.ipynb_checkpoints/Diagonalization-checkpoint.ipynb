# %%
# Import packages
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('diagonalizaton_results.csv')

# %%
df.drop(df[df.Iteration==0].index, inplace=True)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111, projection='3d')
# ax.scatter(2,3,4) # plot the point (2,3,4) on the figure
# plt.show()

# %%
df.head()
# Out:
#     Unnamed: 0  offer_01  offer_02  offer_03   bids_01   bids_02   bids_03  \
# 24           0       0.0       0.0       0.0  0.353815  0.482839  0.352620
# 25           1       0.0       0.0       0.0  1.075765  0.880727  0.596626
# 26           2       0.0       0.0       0.0  1.328176  1.132224  1.493217
# 27           3       0.0       0.0       0.0  0.869774  1.575653  1.484014
# 28           4       0.0       0.0       0.0  1.421277  2.869346  1.552954
#
#     Time  Iteration
# 24    16          1
# 25    17          1
# 26    18          1
# 27    19          1
# 28    20          1

# %%
x=df.bids_01
y=df.Time
z=df.Iteration

# %%
x
# Out:
# 24       0.353815
# 25       1.075765
# 26       1.328176
# 27       0.869774
# 28       1.421277
#            ...
# 11995    0.421099
# 11996    0.316411
# 11997    0.289869
# 11998    1.319412
# 11999    0.298767
# Name: bids_01, Length: 11976, dtype: float64

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

ax.plot(x, y, z, 'gray')

plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot(111)


ax.plot(y, x)

plt.show()

# %%
x=df.bids_01[df.Time==16]
z=df.Iteration[df.Time==16]

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
ax.plot(z, x)
plt.show()

# %%
x=df.bids_01[df.Time==17]
z=df.Iteration[df.Time==17]
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
ax.plot(z, x)
plt.show()

# %%
x=df.bids_01[df.Time==17]
y=df.Time[df.Time==17]
z=df.Iteration[df.Time==17]

fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
ax.scatter(z,x)
plt.show()
