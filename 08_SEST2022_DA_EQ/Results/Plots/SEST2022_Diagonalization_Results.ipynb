# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path='Diagonalization_Data/diagonalizaton_results_'

df_fixed_evs_diag = pd.read_csv(file_path+'Fixed_EVs_DIAG.csv')
df_fixed_pvs_diag = pd.read_csv(file_path+'Fixed_PVs_DIAG.csv')
df_mixed_diag =  pd.read_csv(file_path+'mixed_DIAG.csv')

# %%
df_all = [ df_mixed_diag, df_fixed_evs_diag, df_fixed_pvs_diag]
data_order=['Mixed','Fixed_EVs', 'Fixed_PVs']

# %%
for df in df_all:
    df.drop(df[df.Iteration==0].index, inplace=True)
    df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_fixed_evs_diag.groupby('Time').mean().drop(columns=['Iteration']).reset_index()
# Out:
#     Time  offer_01  offer_02  offer_03  offer_04  offer_05  offer_06  \
# 0     16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     18  0.000000  0.000000  0.000077  0.000057  0.000028  0.000000
# 3     19  0.000729  0.000260  0.000709  0.000835  0.000489  0.000526
# 4     20  0.107967  0.094398  0.118844  0.119569  0.108394  0.119047
# 5     21  0.001570  0.002048  0.002108  0.002199  0.002087  0.002246
# 6     22  0.170687  0.158717  0.158532  0.170660  0.164921  0.175155
# 7     23  0.171552  0.155071  0.188303  0.188438  0.187085  0.191055
# 8     24  0.011809  0.011798  0.012357  0.011467  0.010766  0.012211
# 9     25  0.000717  0.000896  0.000782  0.000659  0.000465  0.000778
# 10    26  0.212967  0.209003  0.230440  0.219400  0.212619  0.220203
# 11    27  0.211572  0.207685  0.230404  0.219203  0.214908  0.219029
# 12    28  0.201822  0.200681  0.220663  0.204706  0.201970  0.202401
# 13    29  0.140255  0.158616  0.168848  0.141971  0.144141  0.152681
# 14    30  0.071181  0.079528  0.079953  0.066703  0.064038  0.061646
# 15    31  0.000663  0.000771  0.000606  0.000525  0.000426  0.000506
# 16    32  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17    33  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18    34  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19    35  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20    36  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21    37  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22    38  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23    39  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#     offer_07  offer_08  offer_09   bids_01   bids_02   bids_03   bids_04  \
# 0   0.000000  0.000000  0.000000  0.066049  0.065377  0.062685  0.072306
# 1   0.000000  0.000000  0.000000  0.144117  0.127562  0.120419  0.132741
# 2   0.000029  0.000026  0.000086  0.206678  0.194907  0.225849  0.243118
# 3   0.000682  0.000449  0.000427  0.235465  0.241014  0.234144  0.267888
# 4   0.120473  0.108532  0.105568  0.334897  0.335701  0.335692  0.335324
# 5   0.002267  0.002026  0.002235  0.302969  0.330520  0.308572  0.329450
# 6   0.172258  0.156980  0.168845  0.595612  0.607318  0.623921  0.660788
# 7   0.188342  0.172210  0.189183  0.637047  0.633444  0.657093  0.634313
# 8   0.012280  0.010086  0.011542  0.204036  0.194511  0.222460  0.219553
# 9   0.000519  0.000633  0.000929  0.155257  0.142101  0.161613  0.165407
# 10  0.224693  0.205052  0.225702  0.464126  0.462402  0.442050  0.442422
# 11  0.213615  0.199129  0.215864  0.566679  0.572072  0.591324  0.585396
# 12  0.203871  0.187506  0.205088  0.679949  0.683327  0.722989  0.685172
# 13  0.160896  0.137340  0.163529  0.383006  0.426906  0.433102  0.434266
# 14  0.052103  0.050017  0.055688  0.329138  0.323379  0.321130  0.322692
# 15  0.000457  0.000462  0.000648  0.228568  0.267892  0.274030  0.257887
# 16  0.000000  0.000000  0.000000  0.144544  0.174835  0.164683  0.157023
# 17  0.000000  0.000000  0.000000  0.114540  0.107711  0.115696  0.128308
# 18  0.000000  0.000000  0.000000  0.093192  0.088151  0.096230  0.243630
# 19  0.000000  0.000000  0.000000  0.072600  0.067270  0.207485  0.255785
# 20  0.000000  0.000000  0.000000  0.194239  0.232037  0.189880  0.069999
# 21  0.000000  0.000000  0.000000  0.192450  0.186082  0.138764  0.053520
# 22  0.000000  0.000000  0.000000  0.103788  0.130644  0.095056  0.057828
# 23  0.000000  0.000000  0.000000  0.051407  0.049247  0.051438  0.046075
#
#      bids_05   bids_06   bids_07   bids_08   bids_09
# 0   0.065234  0.063264  0.061115  0.059372  0.060334
# 1   0.121918  0.126041  0.131941  0.116863  0.117790
# 2   0.225538  0.208630  0.219840  0.218529  0.227645
# 3   0.235127  0.234989  0.258872  0.222231  0.226671
# 4   0.345180  0.335840  0.337883  0.335549  0.339234
# 5   0.331220  0.309758  0.322062  0.310618  0.312696
# 6   0.644837  0.652126  0.661239  0.607654  0.635221
# 7   0.638161  0.654591  0.649361  0.636015  0.675268
# 8   0.218077  0.192123  0.220795  0.198348  0.208051
# 9   0.152928  0.143569  0.158991  0.137450  0.141240
# 10  0.443545  0.442125  0.437842  0.437638  0.438789
# 11  0.586021  0.580618  0.577672  0.565869  0.600109
# 12  0.698584  0.690056  0.694688  0.695069  0.732941
# 13  0.419384  0.395356  0.438927  0.410718  0.418897
# 14  0.323769  0.319623  0.331055  0.330126  0.326381
# 15  0.279105  0.239053  0.291193  0.255339  0.349093
# 16  0.141003  0.144845  0.152938  0.141092  0.201823
# 17  0.123875  0.129042  0.124373  0.115630  0.119680
# 18  0.281872  0.211583  0.087562  0.078144  0.096699
# 19  0.248832  0.279469  0.059845  0.148179  0.056370
# 20  0.061421  0.071895  0.192550  0.182155  0.146327
# 21  0.058137  0.063782  0.150491  0.134815  0.129702
# 22  0.056369  0.060273  0.147775  0.115941  0.112789
# 23  0.048397  0.044481  0.047707  0.046348  0.046196

# %%
offer_col = ['offer_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*offer_col, *time_offer]

# %%
df_fixed_evs_diag.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer].head()
# Out:
#    offer_01  offer_02  offer_03  offer_04  offer_05  offer_06  offer_07  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000077  0.000057  0.000028  0.000000  0.000029
# 3  0.000729  0.000260  0.000709  0.000835  0.000489  0.000526  0.000682
# 4  0.107967  0.094398  0.118844  0.119569  0.108394  0.119047  0.120473
#
#    offer_08  offer_09  Time
# 0  0.000000  0.000000    16
# 1  0.000000  0.000000    17
# 2  0.000026  0.000086    18
# 3  0.000449  0.000427    19
# 4  0.108532  0.105568    20

# %%
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

# %% [markdown]
# # Offers Bids Plots

# %% [markdown]
# ### Offers Bids Plots: All Scenarios All DAs based on time interval

# %%
counter = 0
offer = []
scenario=[]
time=[]
#iterate trough all dataframes and average their offers bids : all DAs in each 3 scenario
for df in df_all:
    temp = df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer].drop('Time',axis=1).mean(axis=1)
    count=16
    for i in temp:
        offer.append(i)
        scenario.append(data_order[counter])
        time.append(count)
        count+=1
    counter+=1

df_compare = pd.DataFrame({'Offers':offer, 'Scenario':scenario, 'Time':time})

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare, x='Time',y='Offers' ,hue='Scenario', ax=ax);

ax.set_title('Average Offers Bids In ALL Scenarios for all DAs', fontsize=12)
ax.set_xlabel('Time Interval',fontsize=12);
ax.set_ylabel('Offers Bid in Megaatt PU',fontsize=12);

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Offers_ALL_Scenarios.png", bbox_inches= 'tight', dpi=200)

# %% [markdown]
# ### Offers Bids Plots: All Scenarios All DAs in horizon

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare.groupby("Scenario").mean().reset_index().drop('Time',axis=1),
            x='Scenario',y='Offers' , ax=ax);

ax.set_title('Average Offers Bids In ALL Scenarios for all DAs', fontsize=14)
ax.set_xlabel('Scenarios',fontsize=14);
ax.set_ylabel('Average Bids in Megaatt PU',fontsize=14);

change_width(ax, .45)

ax.set_yticklabels(ax.get_yticks().round(2), size = 12)
ax.set_xticklabels(ax.get_xticklabels(), size = 12)

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Offers_ALL_Scenarios_Horizon.png", bbox_inches= 'tight', dpi=200)
# Out:
# C:\Users\alire\AppData\Local\Temp/ipykernel_15044/1339276470.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks().round(2), size = 12)

# %% [markdown]
# ### Offers Bids Plots: All Scenarios Based ON DAs Group
# There is 3 groups for DAs having different EVs and PVs penetration
# - group_01 = 2,4,6,8
# - group_02 = 3,9
# - group_03 = 1,5,7

# %%
offer_col = ['offer_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*offer_col, *time_offer]


DA = dict()
for i in range(1,10):
    if i % 2 == 0:
        DA['offer_0'+str(i)] = 'CAT_01'
    elif i % 3 == 0:
        DA['offer_0'+str(i)] = 'CAT_02'
    else:
        DA['offer_0'+str(i)] = 'CAT_03'

#offer = 
# scenario=[] There is one above
#time=[16+i for i in range(24)]


first_iteration = True

for df in df_all:
    temp= df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer]
    if first_iteration:
        df_compare = temp.copy(deep=True)
        first_iteration=False
    else:
        df_compare = pd.concat([df_compare, temp])

# Take the average based on time
df_compare = df_compare.groupby('Time').mean().reset_index()

df_compare = df_compare.melt(id_vars=['Time'], var_name="Category", value_name="Offers")

for key, value in DA.items():
    df_compare.loc[df_compare['Category'] == key, 'Category'] = value

df_compare = df_compare.groupby(['Time','Category']).mean().reset_index()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare, x='Time',y='Offers' ,hue='Category', ax=ax);

ax.set_title('Average Offers Bids In ALL Scenarios Based on DAs Category', fontsize=12)
ax.set_xlabel('Time Interval',fontsize=12);
ax.set_ylabel('Offers Bid in Megaatt PU',fontsize=12);


ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Offers_DAs_Categories.png", bbox_inches= 'tight', dpi=200)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare.groupby("Category").mean().reset_index().drop('Time',axis=1),
            x='Category',y='Offers' , ax=ax);

ax.set_title('Average Offers Bids In ALL Scenarios for all Categories', fontsize=14)
ax.set_xlabel('DAs Cetagory',fontsize=14)
ax.set_ylabel('Average Bid in Megaatt PU',fontsize=14)

change_width(ax, .45)

ax.set_yticklabels(ax.get_yticks().round(2), size = 14)
ax.set_xticklabels(ax.get_xticklabels(), size = 14)

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Offers_ALL_Categories_Horizon.png", bbox_inches= 'tight', dpi=200)
# Out:
# C:\Users\alire\AppData\Local\Temp/ipykernel_15044/2419580402.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks().round(2), size = 14)

# %%
# fig = plt.figure(figsize=(8,6))
# ax = fig.add_subplot(1,1,1)

# ax.bar(df_compare.groupby("Category").mean().reset_index().drop('Time',axis=1)['Category'],
#        df_compare.groupby("Category").mean().reset_index().drop('Time',axis=1)['Offers']
#       )

# %% [markdown]
# ### Offers Bids Scenario Plot

# %%
offer_col = ['offer_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*offer_col, *time_offer]

counter = 0
offer = []
scenario=[]
time=[]
#iterate trough all dataframes and average their offers bids : all DAs in each 3 scenario
for df in df_all:
    temp = df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer].drop('Time',axis=1).mean(axis=1)
    count=16
    for i in temp:
        offer.append(i)
        scenario.append(data_order[counter])
        time.append(count)
        count+=1
    counter+=1

df_compare = pd.DataFrame({'Offers':offer, 'Scenario':scenario, 'Time':time})

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)




sns.barplot(data= df_compare.groupby("Scenario").mean().reset_index().drop('Time',axis=1), 
            x='Scenario',y='Offers' , ax=ax);

ax.set_title('Average Offers Bids In ALL Scenarios for all DAs', fontsize=12)
ax.set_xlabel('Scenario',fontsize=12);
ax.set_ylabel('Average Bids in Megaatt PU',fontsize=12);

change_width(ax, .45) 
# ax.set_yticklabels(ax.get_yticks().round(2), size = 12)
ax.set_xticklabels(ax.get_xticklabels(), size = 12)

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Offers_ALL_Scenarios_Horizon.png", bbox_inches= 'tight', dpi=200)

# %% [markdown]
# # Demand Bids Plots

# %%
demand_col = ['bids_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*demand_col, *time_offer]

# %%
DA = dict()
for i in range(1,10):
    if i % 2 == 0:
        DA['bids_0'+str(i)] = 'CAT_01'
    elif i % 3 == 0:
        DA['bids_0'+str(i)] = 'CAT_02'
    else:
        DA['bids_0'+str(i)] = 'CAT_03'

#offer = 
# scenario=[] There is one above
#time=[16+i for i in range(24)]


first_iteration = True

for df in df_all:
    temp= df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer]
    if first_iteration:
        df_compare = temp.copy(deep=True)
        first_iteration=False
    else:
        df_compare = pd.concat([df_compare, temp])

# Take the average based on time
df_compare = df_compare.groupby('Time').mean().reset_index()

df_compare = df_compare.melt(id_vars=['Time'], var_name="Category", value_name="Demands")

for key, value in DA.items():
    df_compare.loc[df_compare['Category'] == key, 'Category'] = value

df_compare = df_compare.groupby(['Time','Category']).mean().reset_index()

#*************************************************
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare, x='Time',y='Demands' ,hue='Category', ax=ax);

ax.set_title('Average Demands Bids In ALL Scenarios Based on DAs Category', fontsize=14)
ax.set_xlabel('Time Interval',fontsize=14);
ax.set_ylabel('Average Bids in Megaatt PU',fontsize=14);

ax.set_yticklabels(ax.get_yticks().round(2), size = 12)
ax.set_xticklabels(ax.get_xticklabels(), size = 12)

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Demands_DAs_Categories.png", bbox_inches= 'tight', dpi=200)
# Out:
# C:\Users\alire\AppData\Local\Temp/ipykernel_15044/2509215475.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks().round(2), size = 12)

# %% [markdown]
# ### Demand Bids Plots: All Scenarios All DAs

# %%
counter = 0
demand = []
scenario=[]
time=[]
#iterate trough all dataframes and average their offers bids : all DAs in each 3 scenario
for df in df_all:
    temp = df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer].drop('Time',axis=1).mean(axis=1)
    count=16
    for i in temp:
        demand.append(i)
        scenario.append(data_order[counter])
        time.append(count)
        count+=1
    counter+=1

df_compare = pd.DataFrame({'Demands':demand, 'Scenario':scenario, 'Time':time})

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare, x='Time',y='Demands' ,hue='Scenario', ax=ax);

ax.set_title('Average Demands Bids In ALL Scenarios for all DAs', fontsize=12)
ax.set_xlabel('Time Interval',fontsize=12);
ax.set_ylabel('Demands Bid in Megaatt PU',fontsize=12);

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Demands_ALL_Scenarios.png", bbox_inches= 'tight', dpi=200)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare.groupby("Scenario").mean().reset_index().drop('Time',axis=1),
            x='Scenario',y='Demands' , ax=ax);

ax.set_title('Average Demands Bids In ALL Scenarios for all DAs', fontsize=14)
ax.set_xlabel('Scenarios',fontsize=14);
ax.set_ylabel('Average Bid in Megaatt PU',fontsize=14);

change_width(ax, .45) 

ax.set_yticklabels(ax.get_yticks().round(2), size = 12)
ax.set_xticklabels(ax.get_xticklabels(), size = 12)

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Demands_ALL_Scenarios_Horizon.png", bbox_inches= 'tight', dpi=200)
# Out:
# C:\Users\alire\AppData\Local\Temp/ipykernel_15044/569221123.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks().round(2), size = 12)

# %% [markdown]
# # Subplot Both Offers and Demands Together

# %%
demand_col = ['bids_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*demand_col, *time_offer]

counter = 0
demand = []
scenario=[]
time=[]
#iterate trough all dataframes and average their offers bids : all DAs in each 3 scenario
for df in df_all:
    temp = df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer].drop('Time',axis=1).mean(axis=1)
    count=16
    for i in temp:
        demand.append(i)
        scenario.append(data_order[counter])
        time.append(count)
        count+=1
    counter+=1

df_compare = pd.DataFrame({'Demands':demand, 'Scenario':scenario, 'Time':time})


#**********************************************************
offer_col = ['offer_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*offer_col, *time_offer]

counter = 0
offer = []
scenario=[]
time=[]
#iterate trough all dataframes and average their offers bids : all DAs in each 3 scenario
for df in df_all:
    temp = df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()[time_offer].drop('Time',axis=1).mean(axis=1)
    count=16
    for i in temp:
        offer.append(i)
        scenario.append(data_order[counter])
        time.append(count)
        count+=1
    counter+=1

df_offer = pd.DataFrame({'Offers':offer, 'Scenario':scenario, 'Time':time})

df_compare['Offers'] = df_offer['Offers']

df_compare = df_compare.melt(id_vars=['Time','Scenario'], var_name="Bid_Type", value_name="Bid_Value")

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)

sns.barplot(data= df_compare.groupby(["Scenario","Bid_Type"]).mean().reset_index().drop('Time',axis=1),
            x='Scenario',y='Bid_Value', hue='Bid_Type' , ax=ax)

ax.set_title('Average Demands and Offers Bids In ALL Scenarios for all DAs', fontsize=14)
ax.set_xlabel('Scenarios',fontsize=14);
ax.set_ylabel('Average Bids in Megaatt PU',fontsize=14);

# change_width(ax, .45) 

# ax.set_yticklabels(ax.get_yticks().round(2), size = 12)
ax.set_xticklabels(ax.get_xticklabels(), size = 12)

ax.plot()

ax.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Demands_and_Offer_Bids_Scenarios_Horizon.png", bbox_inches= 'tight', dpi=200)

# %% [markdown]
# # Based on Category and Scenarios

# %%
DA_demand = dict()
for i in range(1,10):
    if i % 2 == 0:
        DA_demand['bids_0'+str(i)] = 'CAT_01'
    elif i % 3 == 0:
        DA_demand['bids_0'+str(i)] = 'CAT_02'
    else:
        DA_demand['bids_0'+str(i)] = 'CAT_03'
        
DA_offer = dict()
for i in range(1,10):
    if i % 2 == 0:
        DA_offer['offer_0'+str(i)] = 'CAT_01'
    elif i % 3 == 0:
        DA_offer['offer_0'+str(i)] = 'CAT_02'
    else:
        DA_offer['offer_0'+str(i)] = 'CAT_03'

#**************************************************************
first_iteration = True
counter = 0

for df in df_all:
    temp= df.groupby('Time').mean().drop(columns=['Iteration']).reset_index()
    temp['Scenario']= data_order[counter]
    if first_iteration:
        df_compare = temp.copy(deep=True)
        first_iteration=False
        
    else:
        df_compare = pd.concat([df_compare, temp], axis=0)
    counter += 1    

df_compare = df_compare.reset_index()
df_compare.drop(['index', 'Time'],axis=1, inplace=True)


df_compare = df_compare.groupby('Scenario').mean().reset_index()


#**************************************************************************
offer_col = ['offer_0'+str(x) for x in range(1,10)]
time_offer =['Scenario']
time_offer = [*offer_col, *time_offer]

df_offer = df_compare[time_offer]

#**********************************************************************
demand_col = ['bids_0'+str(x) for x in range(1,10)]
time_demand =['Scenario']
time_demand = [*demand_col, *time_demand]

df_demand = df_compare[time_demand]

#****************************************************************
df_offer = df_offer.melt(id_vars=['Scenario'], var_name="DA_Category", value_name="Bid_Value")

df_demand = df_demand.melt(id_vars=['Scenario'], var_name="DA_Category", value_name="Bid_Value")

#***************************************************************
for key, value in DA_demand.items():
    df_demand.loc[df_demand['DA_Category'] == key, 'DA_Category'] = value

df_demand = df_demand.groupby(['Scenario','DA_Category']).mean().reset_index()

for key,value in DA_offer.items():
    df_offer.loc[df_offer['DA_Category'] == key, 'DA_Category'] = value

df_offer = df_offer.groupby(['Scenario','DA_Category']).mean().reset_index()
#****************************************************************

# fig = plt.figure(figsize=(8,6))
# # axs = fig.add_subplot(1,2)
# axs = plt.subplots(1, 2)
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.barplot(data= df_demand,
            x='DA_Category', y='Bid_Value', hue='Scenario' , ax=axes[0])
axes[0].set_title("Average Demand Bids", fontsize=12)
axes[0].set_xlabel('DAs Categories',fontsize=14);
axes[0].set_ylabel('Average Demands Bids MW-PU',fontsize=14);


sns.barplot(data= df_offer,
            x='DA_Category', y='Bid_Value', hue='Scenario' , ax=axes[1])

axes[1].set_title("Average Offers Bids", fontsize=12)
axes[1].set_xlabel('DAs Categories',fontsize=14);
axes[1].set_ylabel('Average Offers Bids MW-PU',fontsize=14);

fig.suptitle('Average Demands and Offers Bids In ALL Scenarios based on DAs Category',fontsize=14)



#axes.set_title(, )
# ax.set_xlabel('Scenarios',fontsize=14);
# ax.set_ylabel('Average Bids in Megaatt PU',fontsize=14);

# # change_width(ax, .45) 

# # ax.set_yticklabels(ax.get_yticks().round(2), size = 12)
# ax.set_xticklabels(ax.get_xticklabels(), size = 12)

plt.show()
fig.set_rasterized(True)
fig.savefig("Figures_Diganolization/Average_Demands_and_Offer_Bids_Scenarios_DAs_Category.png", bbox_inches= 'tight', dpi=200)

# %%
df_offer
# Out:
#     Scenario DA_Category  Bid_Value
# 0  Fixed_EVs      CAT_01   0.054310
# 1  Fixed_EVs      CAT_02   0.057458
# 2  Fixed_EVs      CAT_03   0.055115
# 3  Fixed_PVs      CAT_01   0.132173
# 4  Fixed_PVs      CAT_02   0.096968
# 5  Fixed_PVs      CAT_03   0.067284
# 6      Mixed      CAT_01   0.099681
# 7      Mixed      CAT_02   0.072591
# 8      Mixed      CAT_03   0.050922

# %%
df_demand
# Out:
#     Scenario DA_Category  Bid_Value
# 0  Fixed_EVs      CAT_01   0.276439
# 1  Fixed_EVs      CAT_02   0.281589
# 2  Fixed_EVs      CAT_03   0.277856
# 3  Fixed_PVs      CAT_01   0.366561
# 4  Fixed_PVs      CAT_02   0.327590
# 5  Fixed_PVs      CAT_03   0.292454
# 6      Mixed      CAT_01   0.327817
# 7      Mixed      CAT_02   0.298809
# 8      Mixed      CAT_03   0.273143

# %% [markdown]
# # Trend of offers bids in all scenarios
#
# - df_all = [ df_mixed_diag, df_fixed_evs_diag, df_fixed_pvs_diag]
# - data_order=['Mixed','Fixed_EVs', 'Fixed_PVs']

# %%
offer_col = ['offer_0'+str(x) for x in range(1,10)]
time_offer =['Time']
time_offer = [*offer_col, *time_offer]

# fig = plt.figure(figsize=(12,10))
# ax = fig.add_subplot(1,1,1)

# sns.lineplot(data = df_mixed_diag, y='offer_02', x=df_mixed_diag.index)


# sns.catplot(data= df_mixed_diag, x='Iteration', y='offer_02', col='Time',  col_wrap=4, height=6, aspect=0.5)
# sns.swarmplot(data= df_mixed_diag, x='Time', y='offer_02', color=".25")


df_compare = df_mixed_diag[offer_col]
df_compare = df_compare.sum(axis=1)

df_compare = pd.DataFrame({'Value':df_compare, 'Time': df_mixed_diag.Time, 'Iteration':df_mixed_diag.Iteration})

# %%
sns.scatterplot(data=df_compare, x='Iteration', y='Value', hue='Time')
# Out:
# <AxesSubplot:xlabel='Iteration', ylabel='Value'>
